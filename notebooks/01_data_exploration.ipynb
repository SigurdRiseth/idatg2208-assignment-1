# %% [markdown]
# # Data Exploration
#
# Load the dataset into a `DataFrame` and display the first 5 rows. Print the dataset information and summary statistics

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Define dataset ID and file path
dataset_id = "yasserh/wine-quality-dataset"
file_path = "WineQT.csv"

# Load the dataset directly into pandas
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    dataset_id,
    file_path
)

# Save the DataFrame as a pickle file
df.to_pickle("../data/winequality.pkl")

# Display the first five rows of the DataFrame
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  Id
# 0            7.4              0.70         0.00  ...      9.4        5   0
# 1            7.8              0.88         0.00  ...      9.8        5   1
# 2            7.8              0.76         0.04  ...      9.8        5   2
# 3           11.2              0.28         0.56  ...      9.8        6   3
# 4            7.4              0.70         0.00  ...      9.4        5   4
#
# [5 rows x 13 columns]

# %% [markdown]
# Which features show the highest variation based on summary statistics?

# %%
# Display summary statistics of the DataFrame
df.describe()
# Out:
#        fixed acidity  volatile acidity  ...      quality           Id
# count    1143.000000       1143.000000  ...  1143.000000  1143.000000
# mean        8.311111          0.531339  ...     5.657043   804.969379
# std         1.747595          0.179633  ...     0.805824   463.997116
# min         4.600000          0.120000  ...     3.000000     0.000000
# 25%         7.100000          0.392500  ...     5.000000   411.000000
# 50%         7.900000          0.520000  ...     6.000000   794.000000
# 75%         9.100000          0.640000  ...     6.000000  1209.500000
# max        15.900000          1.580000  ...     8.000000  1597.000000
#
# [8 rows x 13 columns]

# %% [markdown]
# ## Correlation Analysis
#
# Compute the correlation matrix of all features.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

correlation_matrix = df.corr()

# Plotting the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.rcParams.update({
    "text.usetex": True,                # Use LaTeX for all text
    "font.family": "serif",             # Match your LaTeX font family
    "font.serif": ["New PX"],           # newpxtext/newpxmath font
    "axes.labelsize": 14,               # Size of axis labels
    "axes.titlesize": 14,               # Size of titles
    "xtick.labelsize": 13,
    "ytick.labelsize": 13,
    "legend.fontsize": 13,
    "figure.dpi": 300,                  # High resolution
})

plt.title('Correlation Matrix Heatmap')
plt.savefig("../reports/figures/correlation_matrix.png", 
            bbox_inches="tight",   # don't cut off labels/titles
            dpi=300)               # optional: higher resolution
plt.show()
